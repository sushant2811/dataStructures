# %% [markdown]
# ## Review data structures
#
# ### Ref.: LeetCode and geeksforgeeks

# %%
# Node class
class Node:
    
    def __init__(self, data):
        
        self.data = data # Assign data
        self.next = None # initialize next as null

# %%
# Linked list class

class linkedList:
    
    # function to initialize the linked list object
    
    def __init__(self):
        
        self.head = None

# %% [markdown]
# Let's create a linked list with three nodes

# %%
ll = linkedList()

# %%
type(ll)
# Out:
# __main__.linkedList

# %%
ll.head = Node(11)

# %%
ll

# %%
second = Node(22)

# %%
second

# %%
type(second)
# Out:
# __main__.Node

# %%
second.data
# Out:
# 22

# %%
second.next

# %%
third = Node(33)

# %% [markdown]
# Three nodes have been created, they have values: 11, 22, and 33. Now we gotta link them.

# %%
ll.head.data
# Out:
# 11

# %%
type(ll.head)
# Out:
# __main__.Node

# %%
ll.head.next = second

# %%
second.next = third

# %% [markdown]
# ** Traversing the linked list **

# %%
# Linked list class

class linkedList:
    
    # function to initialize the linked list object
    
    def __init__(self):
        
        self.head = None
        
    
    def printList(self):
        
        node = self.head
        
        while node: 
            
            print(node.data)
            
            node = node.next

# %%
ll = linkedList()

first = Node(11)
second = Node('aa')
third = Node(23.00)

ll.head = first
first.next = second
second.next = third

# %%
ll.printList()
# Out:
# 11
# aa
# 23.0

# %%
second.next

# %%
third.next

# %%
type(third.next)
# Out:
# NoneType

# %% [markdown]
# #### Adding a node to the linked list
#
# **At the start**

# %%
class linkedList:
    
    # function to initialize the linked list object
    
    def __init__(self):
        
        self.head = None
        
    
    def printList(self):
        
        node = self.head
        
        while node: 
            
            print(node.data)
            
            node = node.next
            
    def addNodeAtStart(self, data):
        
        # create a new node
        first = Node(data)
        
        # point the next pointer of the new node to the head of linked list (LL)
        first.next = self.head
        
        # Reassign the head of LL to the new node
        self.head = first

# %%
ll = linkedList()

first = Node(11)
second = Node(22)
third = Node(33)

ll.head = first
first.next = second
second.next = third

# %%
ll.addNodeAtStart(10)

# %%
ll.printList()
# Out:
# 10
# 11
# 22
# 33

# %% [markdown]
# **Add node after a given node in the linked list**

# %%
class linkedList:
    
    # function to initialize the linked list object
    
    def __init__(self):
        
        self.head = None
        
    
    def printList(self):
        
        node = self.head
        
        while node: 
            
            print(node.data)
            
            node = node.next
            
    def addNodeAtStart(self, data):
        
        # create a new node
        first = Node(data)
        
        # point the next pointer of the new node to the head of linked list (LL)
        first.next = self.head
        
        # Reassign the head of LL to the new node
        self.head = first
        
    def addAfterGivenNodeVal(self, prevNodeVal, data):
        
        nodeToAdd = Node(data)
        
        nodeVal = None
        
        node = self.head
        
        while nodeVal != prevNodeVal and node:
            
            nodePrev = node
            nodeVal = node.data
            node = node.next
        
        if node:
            
            nodePrev.next = nodeToAdd
            nodeToAdd.next = node  
            
        else:
            
            print("The given value doesn't exist in the linked list!")

# %%
ll = linkedList()

first = Node(11)
second = Node(22)
third = Node(33)

ll.head = first
first.next = second
second.next = third

# %%
ll.addNodeAtStart(10)

# %%
ll.printList()
# Out:
# 10
# 11
# 22
# 33

# %%
ll.addAfterGivenNodeVal(22, 222)

# %%
ll.printList()
# Out:
# 10
# 11
# 22
# 222
# 33

# %%
ll.addAfterGivenNodeVal(44, 444)
# Out:
# The given value doesn't exist in the linked list!

# %% [markdown]
# ** We added a node after a given node value, let's add the node after the given node **

# %%
class linkedList:
    
    # function to initialize the linked list object
    
    def __init__(self):
        
        self.head = None
        
    
    def printList(self):
        
        node = self.head
        
        while node: 
            
            print(node.data)
            
            node = node.next
            
    def addNodeAtStart(self, data):
        
        # create a new node
        first = Node(data)
        
        # point the next pointer of the new node to the head of linked list (LL)
        first.next = self.head
        
        # Reassign the head of LL to the new node
        self.head = first
        
    def addAfterGivenNodeVal(self, prevNodeVal, data):
        
        nodeToAdd = Node(data)
        
        nodeVal = None
        
        node = self.head
        
        while nodeVal != prevNodeVal and node:
            
            nodePrev = node
            nodeVal = node.data
            node = node.next
        
        if node:
            
            nodePrev.next = nodeToAdd
            nodeToAdd.next = node  
            
        else:
            
            print("The given value doesn't exist in the linked list!")
            
    def addAfterGivenNode(self, prevNode, newData):
        
        newNode = Node(newData)
        
        newNode.next = prevNode.next
        
        prevNode.next = newNode

# %%
ll = linkedList()

first = Node(11)
second = Node(22)
third = Node(33)

ll.head = first
first.next = second
second.next = third
print (third)
print (second.next)
ll.addNodeAtStart(10)
# Out:
# <__main__.Node object at 0x1066cf7f0>
# <__main__.Node object at 0x1066cf7f0>

# %%
ll.printList()
# Out:
# 10
# 11
# 22
# 33

# %%
ll.addAfterGivenNode(first, 111)

# %%
ll.printList()
# Out:
# 10
# 11
# 111
# 22
# 33

# %%
ll.addAfterGivenNode(Node(22), 222)

# %%
ll.printList()
# Out:
# 10
# 11
# 111
# 22
# 33
# 44

# %% [markdown]
# The aboove output makes sense.

# %%
ll.head.next=None
print (ll.head.data
      )
# Out:
# 10

# %%
second3 = Node(22)

# %%
second2.data == second3.data
# Out:
# True

# %%
second2.next == second3.next
# Out:
# True

# %%
second2 == second3
# Out:
# False

# %%
second2

# %%
second3

# %% [markdown]
# second2 and second3 are two different instances of the same class. They point to different memory locations in the heap. Whenever we create an instance of class, the value stored in that instance variable is the memory location of that object in the heap.

# %%
class linkedList:
    
    # function to initialize the linked list object
    
    def __init__(self):
        
        self.head = None
        
    
    def printList(self):
        
        node = self.head
        
        while node: 
            
            print(node.data)
            
            node = node.next
            
    def addNodeAtStart(self, data):
        
        # create a new node
        first = Node(data)
        
        # point the next pointer of the new node to the head of linked list (LL)
        first.next = self.head
        
        # Reassign the head of LL to the new node
        self.head = first
        
    def addAfterGivenNodeVal(self, prevNodeVal, data):
        
        nodeToAdd = Node(data)
        
        node = self.head
        
        if not node:
            
            print("It's an empty linked list!")
            return
        
        nodeVal = node.data
        
        while nodeVal != prevNodeVal:
            
            node = node.next
            
            if not node:
                print("The given value doesn't exist in the linked list!")
                return
            else:
                nodeVal = node.data
                nodeNext = node.next
            
        node.next = nodeToAdd
        nodeToAdd.next = nodeNext  
            
            
    def addAfterGivenNode(self, prevNode, newData):
        
        newNode = Node(newData)
        
        newNode.next = prevNode.next
        
        prevNode.next = newNode
        
    def addAtTheEnd(self, data):
        
        newNode = Node(data)
        
        temp = self.head
        
        while temp and temp.next:
            
            temp = temp.next
        
        # taking care of the edge case that the linked list is empty
        if not temp: 
            self.head = newNode
        else:    
            temp.next = newNode

# %%
ll = linkedList()

first = Node(11)
second = Node(22)
third = Node(33)

ll.head = first
first.next = second
second.next = third

ll.addNodeAtStart(10)

# %%
ll.printList()
# Out:
# 10
# 11
# 22
# 33

# %%
ll.addAfterGivenNodeVal(11, 111)

# %%
ll.printList()
# Out:
# 10
# 11
# 111
# 22
# 33

# %%
ll.addAtTheEnd(44)

# %%
ll.printList()
# Out:
# 10
# 11
# 111
# 22
# 33
# 44

# %%
l2 = linkedList()

# %%
l2.printList()

# %%
l2 = linkedList()
l2.addAtTheEnd(55)
l2.printList()
# Out:
# 55

# %%
l2.printList()

# %%
l2.addNodeAtStart(44)

# %%
l2.printList()
# Out:
# 44

# %%
l3 = linkedList()
l3.addNodeAtStart(33)

# %%
l3.printList()
# Out:
# 33

# %% [markdown]
# ## Doubly linked list

# %%
class NodeDoubleLL: 
    
    def __init__(self):
        
        self.value = None
        
        self.prev = None
        self.next = None

# %%
class DoubleLL:
    
    def __init__(self):
        
        self.head = None

# %% [markdown]
# ## Circular linked list

# %%
class NodeCLL: 
    
    def __init__(self):
        
        self.value = None
        self.next = None

# %%
class CLL:
    
    def __init__(self):
        
        self.head = None

# %% [markdown]
# **Linked list questions**

# %%
class NodeLL:
    
    def __init__(self, val):
        
        self.val = val
        self.next = None

# %%
class LinkedList: 
    
    def __init__(self):
        
        self.head = None
        
    def addNodeAtHead(self, val):
        
        node = NodeLL(val)
        
        if self.head is None:
            
            self.head = node
            
            return
        
        node.next = self.head
        
        self.head = node
        
        return
        
    def printLL(self):
        
        temp = self.head
        
        while temp is not None:
            
            print(temp.val)
            
            temp = temp.next
            
    
    def addNodeAtEnd(self, val):
        
        node = NodeLL(val)
        
        if self.head is None:
            
            self.head = node
            
            return
        
        temp = self.head
        
        while temp and temp.next:
            
            temp = temp.next
            
        temp.next = node
        
        return
    
    
    def deleteAtStart(self):
        
        if self.head:
            
            temp = self.head
            
            self.head = temp.next
            
            temp = None
            
            return
            
        print("Empty linked list. Nothing to delete")
        
        return
        
    
    def deleteAtEnd(self):
        
        """
        We have two edge cases in this case, one is that the list is empty and 
        other is that the list has only one node
        """
        
        if self.head is None:
            
            print("Empty linked list. Nothing to delete")
            
            return
        
        if self.head.next is None:
            
            self.head = None
            
            print("The linked list had just one element. Which has now been deleted")
            
            return
        
        temp = self.head
        
        while temp.next:
            
            prevNode = temp
            
            temp = temp.next
            
        prevNode.next = None
        
        temp = None

# %%
ll = LinkedList()

# %%
ll.addNodeAtHead(10)

# %%
ll.printLL()
# Out:
# 10

# %%
ll.deleteAtEnd()
# Out:
# The linked list had just one element. Which has now been deleted

# %%
ll.printLL()
# Out:
# 30

# %%
ll.addNodeAtHead(20)
ll.addNodeAtHead(30)

# %%
ll.printLL()
# Out:
# 30
# 20
# 10

# %%
ll.addNodeAtEnd(5)

# %%
ll.printLL()
# Out:
# 11
# 5

# %%
ll.addNodeAtEnd(11)

# %%
ll.printLL()
# Out:
# 11

# %%
ll.deleteAtEnd()

# %%
ll.printLL()
# Out:
# 30
# 20
# 10
# 5

# %%
ll.deleteAtStart()

# %%
ll.printLL()
# Out:
# 20
# 10
# 5

# %%
ll.deleteAtStart()
ll.printLL()
# Out:
# 10
# 5

# %%
ll.deleteAtEnd()
ll.printLL()
# Out:
# 10

# %%
ll.deleteAtEnd()

# %%
ll.printLL()
# Out:
# 10

# %%
ll.deleteAtStart()

# %%
ll.printLL()

# %%
ll.deleteAtStart()
# Out:
# Empty linked list. Nothing to delete

# %%
ll.deleteAtEnd()
# Out:
# Empty linked list. Nothing to delete
